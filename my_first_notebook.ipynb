# %% [markdown]
# What is the difference between hardware and software? Give one example of each.
#
# Ans: hardware contains physical things to carry or assembled
# Software contains to run in the machine that required setup
# ```
# # This is formatted as code
# ```
